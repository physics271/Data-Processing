# %%
import pandas as pd
from functools import reduce

# %%
data = pd.read_csv('2015_Greenhouse_Gas_Report-_Data.csv')
data.head()
# Out:
#                                               Source   County  \
# 0  Agrium Kennewick Fertilizer Operations (KFO) -...   Benton
# 1             Air Liquide Hydrogen Plant - Anacortes   Skagit
# 2                     Alcoa Intalco Works - Ferndale  Whatcom
# 3                     Alcoa Wenatchee Works - Malaga   Chelan
# 4                        Ardagh Glass Inc. - Seattle     King
#
#                                           Address  Total Emissions (MT CO2e)  \
# 0         227515 E. Bowles Rd Kennewick, WA 99337                     155888
# 1       8581 South Texas Road Anacortes, WA 98221                      64413
# 2      4050 Mountain View Road Ferndale, WA 98248                    1195786
# 3         6200 Malaga/Alcoa Hwy. Malaga, WA 98828                     331207
# 4  5801 East Marginal Way South Seattle, WA 98134                      76674
#
#    Biogenic CO2 (MT CO2)  Fossil CO2 (MT CO2)  Methane (MT CO2e)  \
# 0                      0                10731                  1
# 1                      0                64413                  0
# 2                      0               418042              10480
# 3                      0               254025                 14
# 4                      0                76614                 27
#
#    Nitrous Oxide (MT CO2e)  Hydrofluorocarbons (MT CO2e)  \
# 0                   145157                             0
# 1                        0                             0
# 2                       34                             0
# 3                       16                             0
# 4                       32                             0
#
#    Perfluorocarbons (MT CO2e)  Sulfur Hexafluoride (MT CO2e)  Other (MT CO2e)  \
# 0                           0                              0                0
# 1                           0                              0                0
# 2                      767230                              0                0
# 3                       77152                              0                0
# 4                           0                              0                0
#
#   Location (Latitude, Longitude)     Sector               Sub Sector  \
# 0        (46.165957, -119.017218)  Chemicals  Nitric Acid Production
# 1        (48.465617, -122.556032)  Chemicals     Hydrogen Production
# 2            (48.8455, -122.7055)     Metals     Aluminum Production
# 3            (47.3567, -120.1273)     Metals     Aluminum Production
# 4          (47.55242, -122.33739)   Minerals        Glass Production
#
#   Clean Air Rule  Energy-Intensive, Trade-Exposed   \
# 0             YES                              YES
# 1              NO                               NO
# 2             YES                              YES
# 3             YES                              YES
# 4             YES                               NO
#
#    Point Size- Based on Total Emissions
# 0                                     3
# 1                                     2
# 2                                     4
# 3                                     3
# 4                                     2

# %% [markdown]
# ### Some Cleanup to Start

# %%
#Defining new column names that do not have random spaces at the end
new_header={data[:0][i].name:data[:0][i].name[0:-1] if data[:0][i].name.endswith(" ") 
            else data[:0][i].name for i in data[:0]}

#Renaming columns
data=data.rename(columns=new_header)

# %%
# Add numerical IDs to rows
data["ID"]=range(data.shape[0])

# %% [markdown]
# ### Sector & Subsector IDs

# %%
#Get sectors
sectors=set(data["Sector"])

#Assign sector IDs
sector_ID={s:i for s,i in zip(sectors, range(len(sectors)))}

#Add column with IDs
data["Sector ID"]=data["Sector"].map(sector_ID)

# %%
#Set up list of subsectors by sector
subsectors=[set()]*len(sectors)

#Make a list of all the sets of subsets, indexed by sector IDs
for subsector,sector in zip(data["Sub Sector"],data["Sector ID"]):
    subsectors[sector]=subsectors[sector].union({subsector})

#Makes sets in above list into dictionaries
temp_subsector_ID=[{s:i for s,i in zip(subs, range(len(subs)))} for subs in subsectors]


#Define function to join dictionaries because this doesn't exist by default
def dict_join(x,y):
    temp_dict=x.copy()
    temp_dict.update(y)
    return(temp_dict)

#Flatten list of dictionaries into one dictionary
subsector_ID=reduce(dict_join, temp_subsector_ID)

#Use dictionary to add column of subsector IDs by sector
data["Sub Sector ID"]=data["Sub Sector"].map(subsector_ID)

# %%
#Some feature combination, though of very questionable value
data["Sector, Subsector ID"]=tuple(zip(data["Sector ID"], data["Sub Sector ID"]))

# %% [markdown]
# ### County IDs

# %%
#Get counties
counties=set(data["County"])

#Assign county IDs
county_ID={c:i for c,i in zip(counties, range(len(counties)))}

#Add column with IDs
data["County ID"]=data["County"].map(county_ID)

# %% [markdown]
# ### Converting Words to Numerical Truth Values

# %%
#Define a dict for converting YES and NO to numerical values
truth_dict={"YES":1, "NO":0}

#Apply dict to applicable columns
data["Clean Air Rule"] = data["Clean Air Rule"].map(truth_dict)
data["Energy-Intensive, Trade-Exposed"]=data["Energy-Intensive, Trade-Exposed"].map(truth_dict)

# %% [markdown]
# ### Splitting Company Names from Cities

# %%
#Get company names and city names by splitting data from Source at " - "
companies, cities=zip(*[i.split(" - ") for i in data["Source"]])

#Make new columns
data["Company"]=companies
data["City"]=cities

# %%
#Make sets
companies_set=set(companies)
cities_set=set(cities)

#Assign IDs
company_ID={c:i for c,i in zip(companies_set, range(len(companies_set)))}
city_ID={c:i for c,i in zip(cities_set, range(len(cities_set)))}

#Add column with IDs
data["Company ID"]=data["Company"].map(company_ID)
data["City ID"]=data["City"].map(city_ID)

# %%
#Another questionably useful feature combination
data["City, County ID"]=tuple(zip(data["City ID"], data["County ID"]))

# %%
data
# Out:
#                                                 Source        County  \
# 0    Agrium Kennewick Fertilizer Operations (KFO) -...        Benton
# 1               Air Liquide Hydrogen Plant - Anacortes        Skagit
# 2                       Alcoa Intalco Works - Ferndale       Whatcom
# 3                       Alcoa Wenatchee Works - Malaga        Chelan
# 4                          Ardagh Glass Inc. - Seattle          King
# ..                                                 ...           ...
# 136         Vertellus Performance Chemicals LLC - Elma  Grays Harbor
# 137                              WaferTech LLC - Camas         Clark
# 138              Washington State University - Pullman       Whitman
# 139  Waste Management Greater Wenatchee Regional La...       Douglas
# 140              Weyerhaeuser Raymond Lumber - Raymond       Pacific
#
#                                             Address  \
# 0           227515 E. Bowles Rd Kennewick, WA 99337
# 1         8581 South Texas Road Anacortes, WA 98221
# 2        4050 Mountain View Road Ferndale, WA 98248
# 3           6200 Malaga/Alcoa Hwy. Malaga, WA 98828
# 4    5801 East Marginal Way South Seattle, WA 98134
# ..                                              ...
# 136              4800 State Route 12 Elma, WA 98541
# 137               5509 NW Parker St Camas, WA 98607
# 138          2660 Grimes Way Pullman, WA 99164-1172
# 139          191 Webb Road East Wenatchee, WA 98802
# 140               51 Ellis Street Raymond, WA 98577
#
#      Total Emissions (MT CO2e)  Biogenic CO2 (MT CO2)  Fossil CO2 (MT CO2)  \
# 0                       155888                      0                10731
# 1                        64413                      0                64413
# 2                      1195786                      0               418042
# 3                       331207                      0               254025
# 4                        76674                      0                76614
# ..                         ...                    ...                  ...
# 136                      17600                      0                17582
# 137                     172725                      0                13050
# 138                      57370                      0                57309
# 139                      31208                      0                    0
# 140                      46229                  45632                    0
#
#      Methane (MT CO2e)  Nitrous Oxide (MT CO2e)  Hydrofluorocarbons (MT CO2e)  \
# 0                    1                   145157                             0
# 1                    0                        0                             0
# 2                10480                       34                             0
# 3                   14                       16                             0
# 4                   27                       32                             0
# ..                 ...                      ...                           ...
# 136                  8                       10                             0
# 137                  6                     7177                         10646
# 138                 28                       34                             0
# 139              31208                        0                             0
# 140                 86                      511                             0
#
#      Perfluorocarbons (MT CO2e)  ...   ID  Sector ID Sub Sector ID  \
# 0                             0  ...    0          6             0
# 1                             0  ...    1          6             1
# 2                        767230  ...    2          0             2
# 3                         77152  ...    3          0             2
# 4                             0  ...    4         11             1
# ..                          ...  ...  ...        ...           ...
# 136                           0  ...  136          6             2
# 137                       78165  ...  137          8             2
# 138                           0  ...  138          5             0
# 139                           0  ...  139          4             0
# 140                           0  ...  140         10             1
#
#     Sector, Subsector ID County ID  \
# 0                 (6, 0)        14
# 1                 (6, 1)        17
# 2                 (0, 2)        19
# 3                 (0, 2)        21
# 4                (11, 1)         4
# ..                   ...       ...
# 136               (6, 2)        16
# 137               (8, 2)        25
# 138               (5, 0)         5
# 139               (4, 0)        27
# 140              (10, 1)         1
#
#                                                Company            City  \
# 0         Agrium Kennewick Fertilizer Operations (KFO)       Kennewick
# 1                           Air Liquide Hydrogen Plant       Anacortes
# 2                                  Alcoa Intalco Works        Ferndale
# 3                                Alcoa Wenatchee Works          Malaga
# 4                                    Ardagh Glass Inc.         Seattle
# ..                                                 ...             ...
# 136                Vertellus Performance Chemicals LLC            Elma
# 137                                      WaferTech LLC           Camas
# 138                        Washington State University         Pullman
# 139  Waste Management Greater Wenatchee Regional La...  East Wenatchee
# 140                        Weyerhaeuser Raymond Lumber         Raymond
#
#      Company ID  City ID  City, County ID
# 0             8       66         (66, 14)
# 1            50       22         (22, 17)
# 2           104       74         (74, 19)
# 3            30       35         (35, 21)
# 4            86        2           (2, 4)
# ..          ...      ...              ...
# 136           5       80         (80, 16)
# 137          78       37         (37, 25)
# 138          52       30          (30, 5)
# 139         101       72         (72, 27)
# 140         112       75          (75, 1)
#
# [141 rows x 28 columns]
